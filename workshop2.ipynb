# %%
import pandas as pd
bank =pd.read_csv('/content/drive/MyDrive/Copy of bank .csv')

# %%
import pandas as pd
#Problem-1(3.1)
#Reading the csv file
df = pd.read_csv("/content/drive/MyDrive/Copy of bank .csv")
#Check info
df.info()

print("\n")

#Selecting columns of dtype objects
df.select_dtypes(include=['object']).columns

#Selecting the unique values of each column
for col in df:
  print("The uniques values of ",col,"=",df[col].unique(),"\n")

print("\n");

#Showing the total number of null values in each column
for col in df:
  print("The total number of null values in ",col,"=",df[col].isnull().sum(),"\n")

#Selecting all columns no objects
df_numeric = df.select_dtypes(exclude=['object'])
print("Columns with dtype object hace been excluded.")

print("\n")

#Storing the numerical data in a new csv file
numeric_csv_file = "banknumericdata.csv"
df_numeric.to_csv(numeric_csv_file, index=False)

#Load the new csv and print its summary
df_numeric_loaded = pd.read_csv(numeric_csv_file)
print(df_numeric_loaded.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
#
#
# The uniques values of  age = [58 44 33 47 35 28 42 43 41 29 53 57 51 45 60 56 32 25 40 39 52 46 36 49
#  59 37 50 54 55 48 24 38 31 30 27 34 23 26 61 22 21 20 66 62 83 75 67 70
#  65 68 64 69 72 71 19 76 85 63 90 82 73 74 78 80 94 79 77 86 95 81 18 89
#  84 87 92 93 88]
#
# The uniques values of  job = ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
#
# The uniques values of  marital = ['married' 'single' 'divorced']
#
# The uniques values of  education = ['tertiary' 'secondary' 'unknown' 'primary']
#
# The uniques values of  default = ['no' 'yes']
#
# The uniques values of  balance = [ 2143    29     2 ...  8205 14204 16353]
#
# The uniques values of  housing = ['yes' 'no']
#
# The uniques values of  loan = ['no' 'yes']
#
# The uniques values of  contact = ['unknown' 'cellular' 'telephone']
#
# The uniques values of  day = [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24 25  1 10 22 31]
#
# The uniques values of  month = ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
#
# The uniques values of  duration = [ 261  151   76 ... 1298 1246 1556]
#
# The uniques values of  campaign = [ 1  2  3  5  4  6  7  8  9 10 11 12 13 19 14 24 16 32 18 22 15 17 25 21
#  43 51 63 41 26 28 55 50 38 23 20 29 31 37 30 46 27 58 33 35 34 36 39 44]
#
# The uniques values of  pdays = [ -1 151 166  91  86 143 147  89 140 176 101 174 170 167 195 165 129 188
#  196 172 118 119 104 171 117 164 132 131 123 159 186 111 115 116 173 178
#  110 152  96 103 150 175 193 181 185 154 145 138 126 180 109 158 168  97
#  182 127 130 194 125 105 102  26 179  28 183 155 112 120 137 124 187 190
#  113 162 134 169 189   8 144 191 184 177   5  99 133  93  92  10 100 156
#  198 106 153 146 128   7 121 160 107  90  27 197 136 139 122 157 149 135
#   30 114  98 192 163  34  95 141  31 199  94 108  29 268 247 253 226 244
#  239 245 204 231 238 258 230 254 265  71 223 246 250 266 240 205 261 259
#  241 260 234 251 225 161 237 262 248 255 220 227 206 224 249 235 228 263
#    2 270 232 252 207 200 269 233 256 273 272 242 264 208 214 222 271 203
#  221 202 216 201 257 229 210 217  75 213  73  76 267 211 215  77 236  82
#    6 209 274   1 243 212 275  80 276   9 279  12 280  88 277  85  84 219
#   24  21 282  41 294  49 329 307 303 331 308 300  64 314 287 330 332 302
#  323 318 333  60 326 335 313 312 305 325 327 336 309 328 322  39 316 292
#  295 310 306 320 317 289  57 321 142 339 301 315 337 334 340 319  17  74
#  148 341 299 344 342 324 345 346 304 281 343 338  14 347  15 291 348 349
#  285 350 284  25 283 278  81   4  87  83  79  70  13 293  37  78  63  22
#  296 355  66  19  35 360 357 354 351 362 358 365 298 286 364 363  47 361
#  288 366 356 352 359 297 367 353 368  42 290  67 371 370 369  50  36 373
#  374 372 311 375 378  59 379  40  18  43  20  69  38 385  56  55  44 391
#   72 390  32  62 399 393  65 377 395 388 389 386  61 412 405 434 394 382
#  459 440 397 383  68 461 462 463 422  51 457 430 442 403 454 428 392 410
#  401 474 475 477 478  54 476 380 479  45  46 495  58  48 518  52 515 520
#  511 536 387 218  33 544 435 436 555 433 446 558 469 616 561 553 384 592
#  467 585 480 421 667 626 426 595 381 376 648 521 452 449 633 398  53 460
#  670 551 414 557 687 404 651 686 425 504 578 674 416 586 411 756 450 745
#  514 417 424 776 396 683 529 439 415 456 407 458 532 481 791 701 531 792
#  413 445 535 784 419 455 491 431 542 470 472 717 437   3 782 728 828 524
#  562 761 492 775 579 493 464 760 466 465 656 831 490 432 655 427 749 838
#  769 587 778 854 779 850 771 594 842 589 603 484 489 486 409 444 680 808
#  485 503 690 772 774 526 420 528 500 826 804 508 547 805 541 543 871 550
#  530]
#
# The uniques values of  previous = [  0   3   1   4   2  11  16   6   5  10  12   7  18   9  21   8  14  15
#   26  37  13  25  20  27  17  23  38  29  24  51 275  22  19  30  58  28
#   32  40  55  35  41]
#
# The uniques values of  poutcome = ['unknown' 'failure' 'other' 'success']
#
# The uniques values of  y = ['no' 'yes']
#
#
#
# The total number of null values in  age = 0
#
# The total number of null values in  job = 0
#
# The total number of null values in  marital = 0
#
# The total number of null values in  education = 0
#
# The total number of null values in  default = 0
#
# The total number of null values in  balance = 0
#
# The total number of null values in  housing = 0
#
# The total number of null values in  loan = 0
#
# The total number of null values in  contact = 0
#
# The total number of null values in  day = 0
#
# The total number of null values in  month = 0
#
# The total number of null values in  duration = 0
#
# The total number of null values in  campaign = 0
#
# The total number of null values in  pdays = 0
#
# The total number of null values in  previous = 0
#
# The total number of null values in  poutcome = 0
#
# The total number of null values in  y = 0
#
# Columns with dtype object hace been excluded.
#
#
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000

# %%
import pandas as pd
#Problem-2(3.1)
#Reading the csv file

df_med = pd.read_csv("/content/drive/MyDrive/Copy of medical_students_dataset.csv")
#Check info
df_med.info()

print("\n")

#Identifing columns with null values
df_med.isnull().sum()

#FIlling the missing values
for col in df_med.columns:
   #Check for missing values
   if df_med[col].isnull().sum() > 0:
    if df_med[col].dtype in ['float64']:
      #Fill with mean because it provides more accurate data by resloving the distorion of data
      df_med[col] = df_med[col].fillna(df_med[col].mean())
      print(f"Filled missing values in column '{col}' with mean.")
    elif df_med[col].dtype == 'object':
      #Fill with mode becaue it is the most frequently occurring value
      df_med[col] = df_med[col].fillna(df_med[col].mode()[0])
      print(f"Filled missing values in column '{col}' with mode.")
print("\n")

#Check for duplicate rows
df_med.duplicated().sum()
#Droping duplicates
if df_med.duplicated().sum() > 0:
    df_med = df_med.drop_duplicates()
    print("Duplicate rows removed.")

print("\n")
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
#
#
# Filled missing values in column 'Student ID' with mean.
# Filled missing values in column 'Age' with mean.
# Filled missing values in column 'Gender' with mode.
# Filled missing values in column 'Height' with mean.
# Filled missing values in column 'Weight' with mean.
# Filled missing values in column 'Blood Type' with mode.
# Filled missing values in column 'BMI' with mean.
# Filled missing values in column 'Temperature' with mean.
# Filled missing values in column 'Heart Rate' with mean.
# Filled missing values in column 'Blood Pressure' with mean.
# Filled missing values in column 'Cholesterol' with mean.
# Filled missing values in column 'Diabetes' with mode.
# Filled missing values in column 'Smoking' with mode.
#
#
# Duplicate rows removed.
#
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 187428 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      187428 non-null  float64
#  1   Age             187428 non-null  float64
#  2   Gender          187428 non-null  object
#  3   Height          187428 non-null  float64
#  4   Weight          187428 non-null  float64
#  5   Blood Type      187428 non-null  object
#  6   BMI             187428 non-null  float64
#  7   Temperature     187428 non-null  float64
#  8   Heart Rate      187428 non-null  float64
#  9   Blood Pressure  187428 non-null  float64
#  10  Cholesterol     187428 non-null  float64
#  11  Diabetes        187428 non-null  object
#  12  Smoking         187428 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 20.0+ MB

# %%
#Promlem-1(3.2)

#Load the dataset
import pandas as pd
df_titanic = pd.read_csv("/content/drive/MyDrive/Copy of Titanic-Dataset.csv")
df_titanic.info()

print("\n")

#Subset the DataFrame for the specified columns
columns_to_keep = ['Name', 'Pclass', 'Sex', 'Age', 'Fare', 'Survived']
subset_df = df_titanic[columns_to_keep]

#Filter rows where 'Pclass' equals 1 (first-class passengers)
first_class_df = subset_df[subset_df['Pclass'] == 1]

#Calculate mean,median,maximum value, and minimum value  for the 'Fare' column
mean_fare = first_class_df['Fare'].mean()
median_fare = first_class_df['Fare'].median()
max_fare = first_class_df['Fare'].max()
min_fare = first_class_df['Fare'].min()

print(f"Mean Fare: {mean_fare}")
print(f"Median Fare: {median_fare}")
print(f"Maximum Fare: {max_fare}")
print(f"Minimum Fare: {min_fare}")

print("\n")

#Problem-2(3.2)
#Checking null values in Age
null_count_in_Age = subset_df["Age"].isnull().sum()
print(f"Number of null values in 'Age' column: {null_count_in_Age}")

print("\n")

#Droping rows where "Age" is null
subset_df.dropna(subset=["Age"])
print(f"Null values have been droped.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
#
# Mean Fare: 84.1546875
# Median Fare: 60.287499999999994
# Maximum Fare: 512.3292
# Minimum Fare: 0.0
#
#
# Number of null values in 'Age' column: 177
#
#
# Null values have been droped.

# %%
#Problem-4(3.2)
import matplotlib.pyplot as plt
# Group the data by 'Sex' and calculate the mean of 'Survived'
survival_by_gender = df_titanic.groupby('Sex')['Survived'].mean()
print(survival_by_gender)

# Plotting the comparison using a bar plot in Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(survival_by_gender.index, survival_by_gender.values, color=['blue', 'red'])

# Adding labels and title
plt.title('Mean Survival Rate by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Mean Survival Rate', fontsize=14)

plt.show()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
